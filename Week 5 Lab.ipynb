# %% [markdown]
# ## Week 5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import squarify

# %% [markdown]
# # 1. Data Science Tools: map(), apply(), lambda

# %%
#Question 1
data = pd.read_csv("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#Question 2
data["Sex_Numeric"] = data["Sex"].map({"female": 1, "male": 0})
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#Question 3
data["Sex_Numeric"].mean()
# Out:
# 0.35241301907968575

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data.shape[0]
#Referring to the total observations of dataset
# Out:
# 891

# %%
data["Sex"].value_counts()/data.shape[0]
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
#4.
np.ceil(10.8)
# Out:
# 11.0

# %%
data.Fare.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
## apply function
data['Fare'].apply(np.ceil)
# Out:
# 0        7.2500
# 1       71.2833
# 2        7.9250
# 3       53.1000
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 8       11.1333
# 9       30.0708
# 10      16.7000
# 11      26.5500
# 12       8.0500
# 13      31.2750
# 14       7.8542
# 15      16.0000
# 16      29.1250
# 17      13.0000
# 18      18.0000
# 19       7.2250
# 20      26.0000
# 21      13.0000
# 22       8.0292
# 23      35.5000
# 24      21.0750
# 25      31.3875
# 26       7.2250
# 27     263.0000
# 28       7.8792
# 29       7.8958
#          ...
# 861     11.5000
# 862     25.9292
# 863     69.5500
# 864     13.0000
# 865     13.0000
# 866     13.8583
# 867     50.4958
# 868      9.5000
# 869     11.1333
# 870      7.8958
# 871     52.5542
# 872      5.0000
# 873      9.0000
# 874     24.0000
# 875      7.2250
# 876      9.8458
# 877      7.8958
# 878      7.8958
# 879     83.1583
# 880     26.0000
# 881      7.8958
# 882     10.5167
# 883     10.5000
# 884      7.0500
# ...

# %%
#5.
drinks = pd.read_csv("drinks.csv")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
#6.
drinks.iloc[:, 1:4].apply(max, axis = 0)
#axis = 0 means reading the data through columns(column-wise)
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64

# %%
#7.
drinks.iloc[:, 1:4].apply(max, axis = 1)
# Out:
# 0        0
# 1      132
# 2       25
# 3      312
# 4      217
# 5      128
# 6      221
# 7      179
# 8      261
# 9      279
# 10      46
# 11     176
# 12      63
# 13       0
# 14     173
# 15     373
# 16     295
# 17     263
# 18      34
# 19      23
# 20     167
# 21     173
# 22     173
# 23     245
# 24      31
# 25     252
# 26      25
# 27      88
# 28      37
# 29     144
#       ...
# 163    178
# 164     90
# 165    186
# 166    280
# 167     35
# 168     15
# 169    258
# 170    106
# 171      4
# 172     36
# 173     36
# 174    197
# 175     51
# 176     51
# 177     71
# 178     41
# 179     45
# 180    237
# 181    135
# 182    219
# 183     36
# 184    249
# 185    220
# 186    101
# 187     21
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Length: 193, dtype: int64

# %%
#8.
drinks.iloc[:, 1:4].apply(np.argmax, axis = 1)
# Out:
# 0        beer_servings
# 1      spirit_servings
# 2        beer_servings
# 3        wine_servings
# 4        beer_servings
# 5      spirit_servings
# 6        wine_servings
# 7      spirit_servings
# 8        beer_servings
# 9        beer_servings
# 10     spirit_servings
# 11     spirit_servings
# 12     spirit_servings
# 13       beer_servings
# 14     spirit_servings
# 15     spirit_servings
# 16       beer_servings
# 17       beer_servings
# 18       beer_servings
# 19       beer_servings
# 20       beer_servings
# 21     spirit_servings
# 22       beer_servings
# 23       beer_servings
# 24       beer_servings
# 25     spirit_servings
# 26       beer_servings
# 27       beer_servings
# 28       beer_servings
# 29       beer_servings
#             ...
# 163    spirit_servings
# 164      beer_servings
# 165      wine_servings
# 166      wine_servings
# 167    spirit_servings
# 168    spirit_servings
# 169    spirit_servings
# 170      beer_servings
# 171      wine_servings
# ...

# %%
#9.
def four_fold(x):
    return 4*x

four_fold(2)
# Out:
# 8

# %%
#10.
drinks["beer_4fold"] = drinks.iloc[:, 1].apply(four_fold)
drinks

##OR
drinks["beer_servings"].apply(lambda x:4*x)
# Out:
# 0         0
# 1       356
# 2       100
# 3       980
# 4       868
# 5       408
# 6       772
# 7        84
# 8      1044
# 9      1116
# 10       84
# 11      488
# 12      168
# 13        0
# 14      572
# 15      568
# 16     1180
# 17     1052
# 18      136
# 19       92
# 20      668
# 21      304
# 22      692
# 23      980
# 24      124
# 25      924
# 26      100
# 27      352
# 28      148
# 29      576
#        ...
# 163     512
# 164     360
# 165     608
# 166     740
# 167      20
# 168       8
# 169     396
# 170     424
# 171       4
# 172     144
# 173     144
# 174     788
# 175     204
# 176     204
# 177      76
# 178      24
# 179     180
# 180     824
# 181      64
# 182     876
# 183     144
# 184     996
# 185     460
# 186     100
# 187      84
# 188    1332
# 189     444
# 190      24
# 191     128
# 192     256
# Name: beer_servings, Length: 193, dtype: int64

# %%
g = lambda x: 4*x
g(3)
# Out:
# 12

# %%
lambda x: 4*x
#Only can use this one time
# Out:
# <function __main__.<lambda>(x)>

# %%
_
# Out:
# <function __main__.<lambda>(x)>

# %%
_(3)
# Out:
# 12

# %%
lambda x,y: x+y
# Out:
# <function __main__.<lambda>(x, y)>

# %%
_(2,5)
# Out:
# 7

# %%
#12.(titanic dataset)

s1 = data[data.Age > 30]
#OR
s1 = data[data['Age'] > 30]
#OR
s1 = data.loc[data.Age > 30, :]

# %%
#13.
s2 = data[(data.Age > 30) & (data.Sex == 'female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# 25            26         1       3
# 40            41         0       3
# 52            53         1       1
# 61            62         1       1
# 85            86         1       3
# 98            99         1       2
# 123          124         1       2
# 132          133         0       3
# 161          162         1       2
# 167          168         0       3
# 177          178         0       1
# 190          191         1       2
# 194          195         1       1
# 195          196         1       1
# 211          212         1       2
# 215          216         1       1
# 218          219         1       1
# 230          231         1       1
# 254          255         0       3
# 258          259         1       1
# ...

# %%
#14.
s3 = data[["PassengerId","Survived","Cabin"]]

# %%
#15.
s4 = data.drop('Cabin', axis = 1)
s4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#16.
data.loc[(data.Sex == 'female')&(data.Age > 30),\
                    ["PassengerId","Survived","Age"]].\
                    sort_values("Age")
#ascending = False 'In descending order'
# Out:
#      PassengerId  Survived   Age
# 767          768         0  30.5
# 318          319         1  31.0
# 396          397         0  31.0
# 18            19         0  31.0
# 215          216         1  31.0
# 801          802         1  31.0
# 797          798         1  31.0
# 328          329         1  31.0
# 218          219         1  32.0
# 657          658         0  32.0
# 190          191         1  32.0
# 123          124         1  32.5
# 412          413         1  33.0
# 472          473         1  33.0
# 506          507         1  33.0
# 85            86         1  33.0
# 809          810         1  33.0
# 759          760         1  33.0
# 576          577         1  34.0
# 98            99         1  34.0
# 516          517         1  34.0
# 416          417         1  34.0
# 3              4         1  35.0
# 279          280         1  35.0
# 269          270         1  35.0
# 211          212         1  35.0
# 258          259         1  35.0
# ...

# %%
#updata: sort by age(descending), and if two rows have the same age, 
#then sort by survived(ascending)
s5 = data.loc[(data.Sex == 'female')&(data.Age > 30),\
                    ["PassengerId","Survived","Age"]].\
                    sort_values(["Age","Survived"],ascending = [False,True])
#ascending = False 'In descending order'

# %%
#17.
data.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
#18.
data.groupby('Pclass')['Fare'].median()
# Out:
# Pclass
# 1    60.2875
# 2    14.2500
# 3     8.0500
# Name: Fare, dtype: float64

# %%
#19.
data.groupby('Sex')['Age'].agg({"Mean": 'mean',
                                "Median": 'median',
                                "Diff": lambda x: x.mean()-x.median()})
# Out:
# /Users/mac/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   after removing the cwd from sys.path.
#              Mean  Median      Diff
# Sex
# female  27.915709    27.0  0.915709
# male    30.726645    29.0  1.726645

# %%
data.groupby('Sex')['Age'].agg(['mean','median',
                                lambda x: x.mean()-x.median()])
# Out:
#              mean  median  <lambda>
# Sex
# female  27.915709    27.0  0.915709
# male    30.726645    29.0  1.726645

# %%
#20.
data.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %%
data.groupby(['Sex','Survived'])['Age'].mean().reset_index()
#reset the index to make it more neat to visualize
# Out:
#       Sex  Survived        Age
# 0  female         0  25.046875
# 1  female         1  28.847716
# 2    male         0  31.618056
# 3    male         1  27.276022

# %%
#21.
data.groupby(['Embarked', 'Pclass'])['Fare'].median().reset_index()
# Out:
#   Embarked  Pclass     Fare
# 0        C       1  78.2667
# 1        C       2  24.0000
# 2        C       3   7.8958
# 3        Q       1  90.0000
# 4        Q       2  12.3500
# 5        Q       3   7.7500
# 6        S       1  52.0000
# 7        S       2  13.5000
# 8        S       3   8.0500

# %%
#22.
data['age_cat'] = data['Age'].apply(lambda x: 'Young' if x <= 50 else "Older")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_Numeric age_cat
# 0      0         A/5 21171   7.2500   NaN        S            0   Young
# 1      0          PC 17599  71.2833   C85        C            1   Young
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1   Young
# ...

# %%
#23.
data['age_cat'] = data['Age'].apply\
                (lambda x: 'Young' if x <= 20 else('Mature' if x <=50 else 'Older'))

# %%
#24.
mpg = pd.read_csv('mpg.csv')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df = mpg.groupby('class').size().reset_index(name = 'counts')
labels = df.apply(lambda x: str(x[0]) + "\n" + '(' + str(x[1]) + ')', axis = 1)
colors = plt.get_cmap('Spectral')(np.linspace(0,1,len(labels)))

# %%
plt.figure()
squarify.plot(sizes = df['counts'], label = labels, color = colors, alpha = 0.6)
plt.axis('off')
plt.title("Treemap of Vechile Class")
plt.show()
